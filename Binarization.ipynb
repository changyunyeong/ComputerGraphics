# %% [markdown]
# <a href="https://colab.research.google.com/github/changyunyeong/ComputerGraphics/blob/main/Binarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/image-photoaidcom-greyscale.jpg', cv2.IMREAD_GRAYSCALE)
ret, th = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(img)
cv2_imshow(th)
# Out:
# <PIL.Image.Image image mode=L size=2000x1333>
# <PIL.Image.Image image mode=L size=2000x1333>
